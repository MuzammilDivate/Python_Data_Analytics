# %% [markdown]
# # MANAGING THE DATAFRAME

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("C:/Users/DELL/Downloads/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# # .head()

# %%
# To acess the first n number of rows of a column theres .head(n)
df.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# # .tail()

# %%
# and for the last n number of rows theres .tail(n)
df.tail(5)
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# ...

# %% [markdown]
# # sample()

# %%
# now those both dont really represent the diversity of the data in the df thats why

df.sample(10)

# this method takes out n number of random rows from the dataframe
# Out:
#               job_title_short                                    job_title  \
# 47243           Data Engineer                                Data Engineer
# 62872        Business Analyst                Business Intelligence Analyst
# 9545             Data Analyst                  lecturer, data analytics/ai
# 626246           Data Analyst                    Lead Finance Data Analyst
# 85371           Data Engineer             Data Security & Privacy Engineer
# 54127       Software Engineer          Software Engineer, Machine Learning
# 342292           Data Analyst                              Sr data analyst
# 44178            Data Analyst     Formador/a Miro Dashboard y Teams Madrid
# 754147         Data Scientist  Junior Data Scientist Real Estate Valuation
# 273344  Senior Data Scientist                        Senior Data Scientist
#
#                        job_location              job_via  \
# 47243   Bengaluru, Karnataka, India      via BeBee India
# ...

# %% [markdown]
# <!-- .copy() -->

# %% [markdown]
# # .copy()

# %%
# Now its not good practice to change the original df so thats why we should make a copy of the 
# original df

df_copy = df.copy()

# and now we have a  copy of the og df. and if we make any changes to the df_copy nothing will happen 
# to our og df

# %%
# now one could argue that we can just do that by saying df_copy = df
# this is just assigining a new variable name to the df now actually creating a seperate copy of it
