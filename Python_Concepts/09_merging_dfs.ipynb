# %% [markdown]
# # Merging Dfs

# %%
import pandas  as pd
import numpy as np

# %%
a = {'name':['rohan', 'rohit', 'md', 'jojo'],
      'roll no':[1, 2, 3, 4]
}
b = {'books':['hahaha', 'hame', 'hiihi'],
      'roll no':[1, 2, 3]
    }

# %%
df1 = pd.DataFrame(a)
df2 = pd.DataFrame(b)

# %%
df1
# Out:
#     name  roll no
# 0  rohan        1
# 1  rohit        2
# 2     md        3
# 3   jojo        4

# %%
df2
# Out:
#     books  roll no
# 0  hahaha        1
# 1    hame        2
# 2   hiihi        3

# %%
# just like SQL it also has left, right, inner, left, cross joins

df1.merge(df2,how='outer', on='roll no')
# Out:
#     name  roll no   books
# 0  rohan        1  hahaha
# 1  rohit        2    hame
# 2     md        3   hiihi
# 3   jojo        4     NaN

# %% [markdown]
# # now lets take a better example

# %%
# ill take the job titles data 

df = pd.read_csv("C:/Users/DELL/Downloads/data_jobs.csv")
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df.head(1)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
#
#     job_location          job_via job_schedule_type  job_work_from_home  \
# 0  Watertown, CT  via Work Nearby         Full-time               False
#
#         search_location     job_posted_date  job_no_degree_mention  \
# 0  Texas, United States 2023-06-16 13:44:15                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States         NaN              NaN
#
#    salary_hour_avg          company_name job_skills job_type_skills
# 0              NaN  Boehringer Ingelheim        NaN             NaN

# %%
dfind = df[df['job_country']=='India']

# %%
dfind.head(3)
# Out:
#    job_title_short          job_title              job_location       job_via  \
# 16   Data Engineer  Big Data Engineer  Pune, Maharashtra, India  via LinkedIn
# 19  Data Scientist     Data Scientist  Pune, Maharashtra, India    via Indeed
# 29  Data Scientist     Data Scientist  Pune, Maharashtra, India    via Exusia
#
#    job_schedule_type  job_work_from_home search_location     job_posted_date  \
# 16         Full-time               False           India 2023-06-15 13:28:03
# 19         Full-time               False           India 2023-04-26 13:20:12
# 29         Full-time               False           India 2023-03-26 13:16:20
#
#     job_no_degree_mention  job_health_insurance job_country salary_rate  \
# 16                  False                 False       India         NaN
# 19                  False                 False       India         NaN
# 29                  False                 False       India         NaN
#
# ...

# %%
dfind['job_posted_month'] = dfind['job_posted_date'].dt.strftime('%B')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_15228\1397181853.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfind['job_posted_month'] = dfind['job_posted_date'].dt.strftime('%B')

# %%
dfind.head()
# Out:
#          job_title_short                                    job_title  \
# 16         Data Engineer                            Big Data Engineer
# 19        Data Scientist                               Data Scientist
# 29        Data Scientist                               Data Scientist
# 38          Data Analyst        Data Quality and Governance Analyst 1
# 42  Senior Data Engineer  Senior Data Engineer(Python)-1563,1637&1633
#
#                   job_location  \
# 16    Pune, Maharashtra, India
# 19    Pune, Maharashtra, India
# 29    Pune, Maharashtra, India
# 38                       India
# 42  Chennai, Tamil Nadu, India
#
#                                               job_via job_schedule_type  \
# 16                                       via LinkedIn         Full-time
# 19                                         via Indeed         Full-time
# 29                                         via Exusia         Full-time
# ...

# %%
df_ind_pivot = dfind.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_ind_pivot.reset_index(inplace=True)

# %%
df_ind_pivot['job_mon_'] = pd.to_datetime(df_ind_pivot['job_posted_month'], format='%B').dt.month

# %%
df_ind_pivot.sort_values('job_mon_', inplace=True)

# %%
df_ind_pivot.set_index('job_posted_month', inplace=True)

# %%
df_ind_pivot.drop(columns='job_mon_', inplace=True)

# %%
df_ind_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  Data Analyst  \
# job_posted_month
# January                        175              31           628
# February                       143              35           433
# March                          116              37           422
# April                          170              32           418
# May                            103              14           278
# June                           146              26           367
# July                           142              25           457
# August                         189              25           618
# September                      155              34           630
# October                        170              36           500
# November                       192              29           722
# December                       186              27           648
#
# job_title_short   Data Engineer  Data Scientist  Machine Learning Engineer  \
# job_posted_month
# ...

# %%
df2 = pd.read_csv('https://lukeb.co/software_csv', index_col='job_posted_month')

# %%
df2
# Out:
#                   Front-End Developer  Back-End Developer  \
# job_posted_month
# January                         13619                9827
# February                        11456                9116
# March                           11102                8178
# April                           14037                9209
# May                             12126                8864
# June                            12003                8065
# July                            11914                8061
# August                          11571                8191
# September                       14016                8447
# October                         11419                8476
# November                        13771                9034
# December                        14033                9232
#
#                   Full-Stack Developer  UI/UX Designer
# job_posted_month
# January                           5108            4348
# February                          7298            4284
# ...

# %%
merged_df = df_ind_pivot.merge(df2, on='job_posted_month')

# %%
top5 = (merged_df
        .sum()
        .sort_values(ascending=False)
        .head()
        .index
        .tolist())

top5
# Out:
# ['Front-End Developer',
#  'Back-End Developer',
#  'Full-Stack Developer',
#  'UI/UX Designer',
#  'Data Engineer']

# %%
import matplotlib.pyplot as plt
merged_df[top5].plot(kind='line')
plt.xlabel('Jobs')
plt.ylabel('job count')
plt.title('median salary of jobs')
plt.ylim(0, 20000)
plt.legend()

# %% [markdown]
# # concatinating two or more datasets using .concat()

# %%
# Ill create two sampla dataframes

data1 = {
    'job_title': ['Data Analyst', 'Data Scientist', 'Machine Learning Engineer'],
    'salary': [60000, 80000, 90000],
    'location': ['New York', 'San Francisco', 'Los Angeles']
}

df1 = pd.DataFrame(data1)

data2 = {
    'job_title': ['Software Engineer', 'Business Analyst', 'Cloud Engineer'],
    'salary': [95000, 70000, 85000],
    'location': ['Seattle', 'Austin', 'Chicago']
}

df2 = pd.DataFrame(data2)

# %%
# then concatinating them 

pd.concat([df1, df2],ignore_index=True)
# Out:
#                    job_title  salary       location
# 0               Data Analyst   60000       New York
# 1             Data Scientist   80000  San Francisco
# 2  Machine Learning Engineer   90000    Los Angeles
# 3          Software Engineer   95000        Seattle
# 4           Business Analyst   70000         Austin
# 5             Cloud Engineer   85000        Chicago

# %%
# Now i wanna try that because muzammil likes to do difficult things for fun hehehe

df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# make a month column with just jan feb kinda values

df['month'] = df['job_posted_date'].dt.strftime('%b')

# %%
df.month.head()
# Out:
# 0    Jun
# 1    Jan
# 2    Oct
# 3    Jul
# 4    Aug
# Name: month, dtype: object

# %%
# now the fun part im breaking the df into different dfs and saving them into a dict its weird to explain but it just makes sense to me so idk

months = df['month'].unique()

dict_months = {month: df[df['month']==month] for month in months}

# %%
dict_months['Jan']
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
# now i only want the quarter of the data so i can do this

quatr1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']])

# %%
quatr1
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 20         Data Scientist                                     Data Scientist
# 39          Data Engineer                                      Data Engineer
# 53          Data Engineer                                      Data Engineer
# 55         Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
# now lets check if it indeed is correct

quatr1['month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='month'>

# %%
df[df.salary_year_avg.notna()]
# Out:
#        job_title_short                                          job_title  \
# 28      Data Scientist                                CRM Data Specialist
# 77       Data Engineer                                      Data Engineer
# 92       Data Engineer            Remote - Data Engineer - Permanent - W2
# 100     Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109       Data Analyst              Senior Supply Chain Analytics Analyst
# ...                ...                                                ...
# 785624   Data Engineer                   Data Analytics Engineer (Hybrid)
# 785641   Data Engineer                                      Data Engineer
# 785648  Data Scientist  Director Data Scientist - Commercial Platforms...
# 785682  Data Scientist  Data Scientist für datengetriebene Entwicklung...
# 785692  Data Scientist               Data Scientist- Hybrid Work Location
#
#                                    job_location          job_via  \
# ...

# %%
df[pd.notna(df['salary_year_avg'])]['salary_year_avg']
# Out:
# 28        109500.0
# 77        140000.0
# 92        120000.0
# 100       228222.0
# 109        89000.0
#             ...
# 785624    139216.0
# 785641    150000.0
# 785648    221875.0
# 785682    157500.0
# 785692    157500.0
# Name: salary_year_avg, Length: 22003, dtype: float64
