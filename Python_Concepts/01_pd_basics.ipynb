# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("C:/Users/DELL/Downloads/data_jobs.csv")

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#        salary_year_avg  salary_hour_avg
# count     22003.000000     10662.000000
# mean     123286.274072        47.016598
# std       48312.449482        21.890738
# min       15000.000000         8.000000
# 25%       90000.000000        27.500000
# 50%      115000.000000        45.980000
# 75%      150000.000000        61.159996
# max      960000.000000       391.000000

# %%
df.iloc[0:10, 1:3]
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
# 5                                  GCP Data Engineer
# 6                  Senior Data Engineer  - GCP Cloud
# 7                                      Data Engineer
# 8           Technology & Operations Business Analyst
# 9                                  Data Scientist II
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC
# 5                      Anywhere
# 6                  Dearborn, MI
# 7                      Anywhere
# 8           Copenhagen, Denmark
# 9                      Anywhere

# %%
df[['job_title', 'job_location']].iloc[0:10]
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
# 5                                  GCP Data Engineer
# 6                  Senior Data Engineer  - GCP Cloud
# 7                                      Data Engineer
# 8           Technology & Operations Business Analyst
# 9                                  Data Scientist II
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC
# 5                      Anywhere
# 6                  Dearborn, MI
# 7                      Anywhere
# 8           Copenhagen, Denmark
# 9                      Anywhere

# %%
df[(df.job_title == 'Data Analyst') & (df.salary_year_avg.notna())]
# Out:
#        job_title_short     job_title                 job_location  \
# 1681      Data Analyst  Data Analyst                   Irvine, CA
# 2390      Data Analyst  Data Analyst                  Midland, TX
# 3237      Data Analyst  Data Analyst               Washington, DC
# 3807      Data Analyst  Data Analyst             Jacksonville, FL
# 4709      Data Analyst  Data Analyst                     Anywhere
# ...                ...           ...                          ...
# 781105    Data Analyst  Data Analyst              Munich, Germany
# 781263    Data Analyst  Data Analyst                 New York, NY
# 782979    Data Analyst  Data Analyst                 Oslo, Norway
# 785187    Data Analyst  Data Analyst             Lisbon, Portugal
# 785515    Data Analyst  Data Analyst  Bengaluru, Karnataka, India
#
#                 job_via job_schedule_type  job_work_from_home  \
# 1681    via Ai-Jobs.net         Full-time               False
# ...

# %%
df['job_posted_date'][0] #its in string format but it should be in datetime format
print(type(df['job_posted_date']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
#Turing this into a datetime object using pandas pd.to_datetime()
pd.to_datetime(df['job_posted_date'])
# Out:
# 0        2023-06-16 13:44:15
# 1        2023-01-14 13:18:07
# 2        2023-10-10 13:14:55
# 3        2023-07-04 13:01:41
# 4        2023-08-07 14:29:36
#                  ...
# 785736   2023-03-13 06:16:16
# 785737   2023-03-12 06:18:18
# 785738   2023-03-12 06:32:36
# 785739   2023-03-12 06:32:15
# 785740   2023-03-13 06:16:31
# Name: job_posted_date, Length: 785741, dtype: datetime64[ns]

# %%
#now assiging it to the original job_posted_date column
#putting it in a datetime format we can perform many actions on it 
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.job_posted_date.dt.month #With this i can get the month out of the datetime
# Out:
# 0          6
# 1          1
# 2         10
# 3          7
# 4          8
#           ..
# 785736     3
# 785737     3
# 785738     3
# 785739     3
# 785740     3
# Name: job_posted_date, Length: 785741, dtype: int32

# %%
# i can create a column to add these values to the df
df['job_posted_month'] = df.job_posted_date.dt.month
#and done we added a column to the df

# %%
#When inspected the df you can see that its in a unordered manner 
# I can order it by using the pandas df.sort_values() function it takes two args (by, and inplace)
df.sort_values('job_posted_date', inplace=True)

# %%
# Now if i check the df i can see the data is ordered in a manner by the date 
df.head()
# Out:
#             job_title_short                                  job_title  \
# 108804         Data Analyst                               Data Analyst
# 96906          Data Analyst                               Data Analyst
# 98438          Data Analyst                               Data Analyst
# 110290         Data Analyst                               Data Analyst
# 72158   Senior Data Analyst  Senior Data Analyst / Platform Experience
#
#           job_location            job_via job_schedule_type  \
# 108804    New York, NY  via CareerBuilder         Full-time
# 96906   Bloomfield, CT  via CareerBuilder         Full-time
# 98438   Washington, DC  via CareerBuilder         Full-time
# 110290     Fairfax, VA  via CareerBuilder         Full-time
# 72158    Worcester, MA       via LinkedIn         Full-time
#
#         job_work_from_home          search_location     job_posted_date  \
# 108804               False  New York, United States 2023-01-01 00:00:04
# ...

# %%
# Dropping a column thats not necessary
# one way to do this is by doing >>>
df.drop(columns='salary_hour_avg')

# The other way is through defining the axis on which you wanna drop the data
df.drop('salary_hour_avg', axis=1)

# I havent used inplace=True so this wont affect the og df
# Out:
#                   job_title_short  \
# 108804               Data Analyst
# 96906                Data Analyst
# 98438                Data Analyst
# 110290               Data Analyst
# 72158         Senior Data Analyst
# ...                           ...
# 362129              Data Engineer
# 351830              Data Engineer
# 327439              Data Engineer
# 112373        Senior Data Analyst
# 90102   Machine Learning Engineer
#
#                                                 job_title  \
# 108804                                       Data Analyst
# 96906                                        Data Analyst
# 98438                                        Data Analyst
# 110290                                       Data Analyst
# 72158           Senior Data Analyst / Platform Experience
# ...                                                   ...
# 362129                                      Data engineer
# 351830                                      Data engineer
# ...

# %%
df.drop(columns='salary_hour_avg', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785741 entries, 108804 to 90102
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  company_name           785723 non-null  object
# ...

# %%
# now if i wanna remove the rows i can use df.dropna() but this removes all the rows which have a null value in them
# if i wanna remove all the rows which have  null in a parrticular column ill have to use the arg subset=[]

df.dropna(subset=['salary_year_avg'], inplace=True)

# all the rows where salary_year_avg was null were dropped

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22003 entries, 108883 to 327439
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        22003 non-null  object
#  1   job_title              22003 non-null  object
#  2   job_location           21723 non-null  object
#  3   job_via                22003 non-null  object
#  4   job_schedule_type      21987 non-null  object
#  5   job_work_from_home     22003 non-null  bool
#  6   search_location        22003 non-null  object
#  7   job_posted_date        22003 non-null  datetime64[ns]
#  8   job_no_degree_mention  22003 non-null  bool
#  9   job_health_insurance   22003 non-null  bool
#  10  job_country            22003 non-null  object
#  11  salary_rate            22003 non-null  object
#  12  salary_year_avg        22003 non-null  float64
#  13  company_name           22003 non-null  object
# ...

# %%
# Now we dont need to remove all those columns as well be needing those for our analysis so ill bring them back 

df = pd.read_csv("C:/Users/DELL/Downloads/data_jobs.csv")

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location      job_posted_date  \
# ...

# %%
# Now a bit of a cleanup

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.describe()
# Out:
#                      job_posted_date  salary_year_avg  salary_hour_avg
# count                         785741     22003.000000     10662.000000
# mean   2023-06-25 16:02:11.860248576    123286.274072        47.016598
# min              2023-01-01 00:00:04     15000.000000         8.000000
# 25%              2023-03-20 10:05:48     90000.000000        27.500000
# 50%              2023-06-29 06:11:38    115000.000000        45.980000
# 75%              2023-09-27 01:01:16    150000.000000        61.159996
# max              2023-12-31 23:59:58    960000.000000       391.000000
# std                              NaN     48312.449482        21.890738

# %%
#The min salary for the column looks very suspicious no? i mean comeon what kinda job pays 15k lets look into that

min_salary = df['salary_year_avg'].idxmin()

# %%
df.iloc[[min_salary]]
# Out:
#        job_title_short               job_title job_location       job_via  \
# 665729   Data Engineer  Data Engineer - Hadoop       Brazil  via LinkedIn
#
#        job_schedule_type  job_work_from_home search_location  \
# 665729         Full-time               False          Brazil
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 665729 2023-12-09 10:05:30                   True                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 665729      Brazil        year          15000.0              NaN
#
#            company_name                                         job_skills  \
# 665729  Net2Source Inc.  ['java', 'python', 'oracle', 'aws', 'hadoop', ...
#
#                                           job_type_skills
# 665729  {'cloud': ['oracle', 'aws'], 'libraries': ['ha...

# %%
#Turns out 15k is a huge salary in Brazil for a data analyst my bad

# %%
df['job_title_short'].unique() #-> Gets all the unique values in that column
# Out:
# array(['Senior Data Engineer', 'Data Analyst', 'Data Engineer',
#        'Business Analyst', 'Data Scientist', 'Machine Learning Engineer',
#        'Senior Data Analyst', 'Cloud Engineer', 'Senior Data Scientist',
#        'Software Engineer'], dtype=object)

# %%
#Tho the above method is getting me all the unique values but its not providing me the counts of all the values that belong to that unique value
# For that i can use the .value_counts() method

df.job_title_short.value_counts()

#TADA
# Out:
# job_title_short
# Data Analyst                 196075
# Data Engineer                186241
# Data Scientist               172286
# Business Analyst              49063
# Software Engineer             44929
# Senior Data Engineer          44563
# Senior Data Scientist         36957
# Senior Data Analyst           29216
# Machine Learning Engineer     14080
# Cloud Engineer                12331
# Name: count, dtype: int64

# %%
df.groupby('job_title_short')['salary_year_avg'].min() #-> Gets the min yearly salary average for each unique value in the job title 
                                                       # short column. Basically groups the data by the unique values in that column

# Now  i can use a bunch of methods on this like mean, median, max, mode, std and stuff
# Out:
# job_title_short
# Business Analyst             16500.0
# Cloud Engineer               42000.0
# Data Analyst                 25000.0
# Data Engineer                15000.0
# Data Scientist               27000.0
# Machine Learning Engineer    30000.0
# Senior Data Analyst          30000.0
# Senior Data Engineer         35000.0
# Senior Data Scientist        45000.0
# Software Engineer            28000.0
# Name: salary_year_avg, dtype: float64

# %%
# I can also group by multiple columns 

df.groupby(['job_title_short', 'job_location'])['salary_year_avg'].median()
# Out:
# job_title_short    job_location
# Business Analyst   's-Graveland, Netherlands                          NaN
#                    's-Hertogenbosch, Netherlands                      NaN
#                    10th of Ramadan City, Egypt                        NaN
#                    6th of October City, Egypt                         NaN
#                    A Coruña, Spain                                    NaN
#                                                                        ..
# Software Engineer  Ümraniye, Elmalıkent, Ümraniye/İstanbul, Türkiye   NaN
#                    İstanbul, Turkey                                   NaN
#                    İstanbul, Türkiye                                  NaN
#                    Łódź, Poland                                       NaN
#                    Žilina, Slovakia                                   NaN
# Name: salary_year_avg, Length: 42721, dtype: float64

# %%
df.groupby('job_title_short')[['salary_year_avg', 'salary_hour_avg']].median()
# Out:
#                            salary_year_avg  salary_hour_avg
# job_title_short
# Business Analyst                   85000.0        40.362499
# Cloud Engineer                     90000.0        40.000000
# Data Analyst                       90000.0        32.615002
# Data Engineer                     125000.0        58.500000
# Data Scientist                    127500.0        47.500000
# Machine Learning Engineer         106415.0        47.535000
# Senior Data Analyst               111175.0        47.500000
# Senior Data Engineer              147500.0        61.500000
# Senior Data Scientist             155500.0        47.620003
# Software Engineer                  99150.0        47.560001

# %%
# Now if i wanna do more than one aggregate functions on one column i can use the agg() function 

df.groupby('job_title_short')['salary_year_avg'].agg(['min', 'median', 'max']) #-> tho i gotta provide the string values of the function
# Out:
#                                min    median       max
# job_title_short
# Business Analyst           16500.0   85000.0  387460.0
# Cloud Engineer             42000.0   90000.0  280000.0
# Data Analyst               25000.0   90000.0  650000.0
# Data Engineer              15000.0  125000.0  525000.0
# Data Scientist             27000.0  127500.0  960000.0
# Machine Learning Engineer  30000.0  106415.0  325000.0
# Senior Data Analyst        30000.0  111175.0  425000.0
# Senior Data Engineer       35000.0  147500.0  425000.0
# Senior Data Scientist      45000.0  155500.0  890000.0
# Software Engineer          28000.0   99150.0  375000.0

# %% [markdown]
# Lets do some analysis based on a specific country

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  datetime64[ns]
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
# ...

# %%
df.job_location.value_counts().head(20)
#Damm india is like in the top ten
# Out:
# job_location
# Anywhere                                                     69552
# Singapore                                                    23415
# Paris, France                                                12311
# Bengaluru, Karnataka, India                                  11474
# London, UK                                                   10564
# Madrid, Spain                                                 9787
# New York, NY                                                  8165
# India                                                         7660
# United States                                                 7454
# Hong Kong                                                     7341
# Lisbon, Portugal                                              7171
# Atlanta, GA                                                   7148
# Hyderabad, Telangana, India                                   6841
# Dublin, Ireland                                               6559
# ...

# %%
indian_jobs = df[df['job_country'].isin(['India'])]
#ORR i can also use df[df['job_country']=='India']

# %%
indian_jobs #-> Now this df has a lot of nan values so lets fix that
# Out:
#              job_title_short  \
# 16             Data Engineer
# 19            Data Scientist
# 29            Data Scientist
# 38              Data Analyst
# 42      Senior Data Engineer
# ...                      ...
# 785712         Data Engineer
# 785715          Data Analyst
# 785716     Software Engineer
# 785718      Business Analyst
# 785740     Software Engineer
#
#                                                 job_title  \
# 16                                      Big Data Engineer
# 19                                         Data Scientist
# 29                                         Data Scientist
# 38                  Data Quality and Governance Analyst 1
# 42            Senior Data Engineer(Python)-1563,1637&1633
# ...                                                   ...
# 785712                     India - Collections Analyst II
# 785715  Amul Careers 2023 - Apply Online - Data Analys...
# 785716                        Application Support Analyst
# ...

# %%
indian_jobs = indian_jobs[indian_jobs['salary_year_avg'].notna()]

# %%
indian_jobs
# Out:
#                   job_title_short  \
# 1209    Machine Learning Engineer
# 2022                Data Engineer
# 2785                Data Engineer
# 3190         Senior Data Engineer
# 3930               Data Scientist
# ...                           ...
# 783733      Senior Data Scientist
# 784033               Data Analyst
# 784768             Data Scientist
# 785395              Data Engineer
# 785515               Data Analyst
#
#                                                 job_title  \
# 1209                      Computer Vision Developer (R&D)
# 2022                       Data Engineer - SQL (Power BI)
# 2785    Staff Software Engineer - Data Engineering (Ja...
# 3190         Senior Big Data DevOps & Deployment Engineer
# 3930                                  Lead Data Scientist
# ...                                                   ...
# 783733                              Senior Data Scientist
# 784033                           Recruitment Data Analyst
# ...

# %%
indian_jobs.groupby('job_title_short')[['salary_year_avg']].mean() #-> TADA
# Out:
#                            salary_year_avg
# job_title_short
# Business Analyst              82255.125000
# Data Analyst                  99149.925532
# Data Engineer                123312.390533
# Data Scientist               118203.690217
# Machine Learning Engineer    111372.570175
# Senior Data Analyst          105740.592593
# Senior Data Engineer         132148.631579
# Senior Data Scientist        126035.787879
# Software Engineer             78420.377778

# %%
indian_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max'])
# Out:
#                              median      min       max
# job_title_short
# Business Analyst            64800.0  43200.0  142025.0
# Data Analyst               100500.0  32400.0  650000.0
# Data Engineer              147500.0  43200.0  249000.0
# Data Scientist             114008.0  43200.0  204381.0
# Machine Learning Engineer   79200.0  32500.0  267000.0
# Senior Data Analyst        111175.0  64800.0  177283.0
# Senior Data Engineer       147500.0  35000.0  181765.0
# Senior Data Scientist      149653.0  64800.0  170575.0
# Software Engineer           79200.0  44418.5  200000.0

# %%
#Now lets sort this data by the median column
df_for_india = indian_jobs.groupby('job_title_short')['salary_year_avg'].agg(['median', 'min', 'max']).sort_values('median')

# %% [markdown]
# NOW VISUALIZING THE DATA USING MATPLOTLIB

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y)

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df['job_posted_month'] = df.job_posted_date.dt.month

# %%
monthly_jobs = df.job_posted_month.value_counts().sort_index()

# %%
plt.plot(monthly_jobs.index, monthly_jobs)
plt.xticks(np.arange(1, len(monthly_jobs)+1))
plt.show()

# %%
jobs = df.job_title_short.value_counts().sort_values(ascending=True)

# %%
plt.barh(jobs.index, jobs)
plt.xlabel('Job counts')
plt.ylabel('Jobs')
plt.title('Counts of Jobs')
# Out:
# Text(0.5, 1.0, 'Counts of Jobs')

# %%
plt.bar(jobs.index, jobs)
plt.xlabel('Job counts')
plt.ylabel('Jobs')
plt.xticks(rotation=45, ha='right')
plt.title('Counts of Jobs')
# Out:
# Text(0.5, 1.0, 'Counts of Jobs')

# %%
jobs.plot(kind='bar')
# Out:
# <Axes: xlabel='job_title_short'>

# %%
df.plot(x='job_posted_month', y='salary_year_avg', kind='line') #-> YEAA this shit doesnt make any sense
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
jobs_df = df.groupby('job_title_short')['salary_year_avg'].median().sort_values()

# %%
jobs_df.plot(kind='barh')
plt.title("Salaries based on Job titles")
plt.xlabel('Salary ($USD)')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
